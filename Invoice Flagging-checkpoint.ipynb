# %% [markdown]
# # Flagging Vendor Invoices for Manual Review
#
# Objective : Predict whether a vendor invoice should be flagged for manual approval based on abnormal cost,freight,or delivery patterns,in order to reduce financial risk,improve operational efficiency,and priortize human review where it adds the most value.
# Manual invoice review is time-consumung and does not scale with transcaction volumne.
# Abnormal freght charges,pricing deviations, or delivery delays often indicate errors,disputes,or compliance risks.
# An automated flagging sysytem enables finance teams to focus attention on high-risk invoices while allowing low-risk invoices to be processed automatically.

# %%
import sqlite3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect(r'D:\Machine Learning Project (Data Science)\data\inventory.db')

# %%
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type ='table'",conn)
for table in tables['name']:
    print(f'Table name: {table}')
    display(pd.read_sql(f"select * from {table} limit 5",conn))
# Out:
# Table name: purchases
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
purchase_agg_df = pd.read_sql_query("""
select 
p.PONumber,
count(distinct p.Brand) as total_brands,
sum(p.Quantity) as total_item_quantity,
sum(p.Dollars) as total_item_dollars,
avg(julianday(p.ReceivingDate) - julianday(p.PODate)) as avg_receiving_delay
from purchases p 
group by p.PONumber
""",conn)

# %%
purchase_agg_df.shape
# Out:
# (5543, 5)

# %%
df = pd.read_sql_query("""
SELECT
    vi.PONumber,
    vi.Quantity AS invoice_quantity,
    vi.Dollars AS invoice_dollars,
    vi.Freight,
    (julianday(vi.InvoiceDate) - julianday(vi.PODate)) AS days_po_to_invoice,
    (julianday(vi.PayDate) - julianday(vi.InvoiceDate)) AS days_to_pay
FROM vendor_invoice vi
""", conn)

# %%
pd.read_sql_query("""
WITH purchase_agg AS (
    SELECT 
        p.PONumber,
        COUNT(DISTINCT p.Brand) AS total_brands,
        SUM(p.Quantity) AS total_item_qunatity,
        SUM(p.Dollars) AS total_item_dollars,
        AVG(julianday(p.ReceivingDate) - julianday(p.PODate)) AS avg_receiving_delay
    FROM purchases p 
    Group BY p.PONumber
)
SELECT
    vi.PONumber,
    vi.Quantity AS invoice_quantity,
    vi.Dollars AS invoice_dollars,
    vi.Freight,
    (julianday(vi.InvoiceDate) - julianday(vi.PODate)) AS days_po_to_invoice,
    (julianday(vi.PayDate) - julianday(vi.InvoiceDate)) AS days_to_pay,
    pa.total_brands,
    pa.total_item_qunatity,
    pa.total_item_dollars,
    pa.avg_receiving_delay

FROM vendor_invoice vi
LEFT JOIN purchase_agg pa
    On vi.PONumber = pa.PONumber
""",conn)
# Out:
#       PONumber  invoice_quantity  invoice_dollars  Freight  \
# 0         8124                 6           214.26     3.47
# 1         8137                15           140.55     8.57
# 2         8169                 5           106.60     4.61
# 3         8106             10100        137483.78  2935.20
# 4         8170              1935         15527.25   429.20
# ...        ...               ...              ...      ...
# 5538     13626                90          1563.00     8.60
# 5539     13661              4617         37300.48   186.50
# 5540     13643              9848        202815.78   932.95
# 5541     13602             24747        149007.56   819.54
# 5542     13574               437          3608.11    16.60
#
#       days_po_to_invoice  days_to_pay  total_brands  total_item_qunatity  \
# 0                   14.0         43.0             1                    6
# 1                   16.0         45.0             2                   15
# ...

# %%
df.isnull().sum()
# Out:
# PONumber              0
# invoice_quantity      0
# invoice_dollars       0
# Freight               0
# days_po_to_invoice    0
# days_to_pay           0
# dtype: int64

# %%
df.dtypes
# Out:
# PONumber                int64
# invoice_quantity        int64
# invoice_dollars       float64
# Freight               float64
# days_po_to_invoice    float64
# days_to_pay           float64
# dtype: object

# %%
def create_invoice_risk_label(row):

    try:
        if abs(row["invoice_dollars"] - row["total_item_dollars"]) > 1:
            return 1

        if row["avg_receiving_delay"] > 5:
            return 1

    except Exception as e:
        return 0

    return 0

df["flag_invoice"] = df.apply(create_invoice_risk_label, axis=1)

print(df["flag_invoice"].value_counts())
# Out:
# flag_invoice
# 0    5543
# Name: count, dtype: int64

# %%
df["flag_invoice"].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='flag_invoice'>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.iloc[:,1:-1].corr(),annot=True)
plt.show()

# %%
flagged = df[df['flag_invoice']==1]
normal = df[df['flag_invoice']==0]

# %%
significant_features = []
non_significant_features = []
results = []

# %%
metrics = ['invoice_quantity' ,'invoice_dollars','Freight',
        'days_po_to_invoice','days_to_pay','total_brands',
        'total_item_qunatity','total_item_dollars','avg_receiving_delay']

# %%
from scipy.stats import ttest_ind

significant_features = []
non_significant_features = []
results = []

for metric in metrics:

    # Skip if column missing
    if metric not in flagged.columns or metric not in normal.columns:
        print(f"Skipping {metric} (not found)")
        continue

    # Skip if insufficient data
    if len(flagged[metric].dropna()) < 2 or len(normal[metric].dropna()) < 2:
        print(f"Skipping {metric} (not enough data)")
        continue

    flagged_mean = flagged[metric].mean()
    normal_mean = normal[metric].mean()

    t_stat, p_value = ttest_ind(
        flagged[metric].dropna(),
        normal[metric].dropna(),
        equal_var=False
    )

    if p_value < 0.05:
        significant_features.append(metric)
        results.append({
            "metric": metric,
            "flagged_mean": round(flagged_mean, 2),
            "normal_mean": round(normal_mean, 2),
            "p_value": round(p_value, 3)
        })
    else:
        non_significant_features.append(metric)
# Out:
# Skipping invoice_quantity (not enough data)
# Skipping invoice_dollars (not enough data)
# Skipping Freight (not enough data)
# Skipping days_po_to_invoice (not enough data)
# Skipping days_to_pay (not enough data)
# Skipping total_brands (not found)
# Skipping total_item_qunatity (not found)
# Skipping total_item_dollars (not found)
# Skipping avg_receiving_delay (not found)
